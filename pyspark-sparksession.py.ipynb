# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[1]") \
                    .appName('SparkByExamples.com') \
                    .getOrCreate()

print("First SparkContext:");
print("APP Name :"+spark.sparkContext.appName);
print("Master :"+spark.sparkContext.master);

sparkSession2 = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExample-test") \
      .getOrCreate();

print("Second SparkContext:")
print("APP Name :"+sparkSession2.sparkContext.appName);
print("Master :"+sparkSession2.sparkContext.master);


sparkSession3 = SparkSession.newSession

print("Second SparkContext:")
print("APP Name :"+sparkSession3.sparkContext.appName);
print("Master :"+sparkSession3.sparkContext.master);
# Out:
# First SparkContext:
# APP Name :Databricks Shell
# Master :local[8]
# Second SparkContext:
# APP Name :Databricks Shell
# Master :local[8]
# Second SparkContext:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <command-2820217326053941>:24
#      21 sparkSession3 = SparkSession.newSession
#      23 print("Second SparkContext:")
# ---> 24 print("APP Name :"+sparkSession3.sparkContext.appName);
#      25 print("Master :"+sparkSession3.sparkContext.master)
#
# AttributeError: 'function' object has no attribute 'sparkContext'
