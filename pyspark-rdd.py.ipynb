# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()

print(spark)
rdd=spark.sparkContext.parallelize([1,2,3,4,56])
print("RDD count :"+str(rdd.count()))

rdd = spark.sparkContext.emptyRDD
print(rdd)
rdd2 = spark.sparkContext.parallelize([])
print(rdd2)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f6e71f05400>
# RDD count :5
# <bound method SparkContext.emptyRDD of <SparkContext master=local[8] appName=Databricks Shell>>
# ParallelCollectionRDD[270] at readRDDFromInputStream at PythonRDD.scala:435
